# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
df=pd.read_csv("car_mpg.csv")
df
# Out:
#    Engine_Size  Cylinders  Horsepower  Weight  Model_Year  Acceleration  MPG
# 0          1.6          4         110    1150        2012          12.5   32
# 1          1.8          4         130    1250        2014          11.0   30
# 2          2.0          4         150    1350        2015          10.5   28
# 3          2.2          4         160    1400        2016          10.0   26
# 4          2.4          4         170    1500        2017           9.8   25
# 5          2.5          4         175    1550        2018           9.5   24
# 6          3.0          6         200    1700        2014           8.7   22
# 7          3.2          6         220    1800        2015           8.4   21
# 8          3.5          6         250    1900        2016           8.0   19
# 9          4.0          8         300    2100        2017           7.2   16

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Engine_Size   10 non-null     float64
#  1   Cylinders     10 non-null     int64
#  2   Horsepower    10 non-null     int64
#  3   Weight        10 non-null     int64
#  4   Model_Year    10 non-null     int64
#  5   Acceleration  10 non-null     float64
#  6   MPG           10 non-null     int64
# dtypes: float64(2), int64(5)
# memory usage: 692.0 bytes

# %%
df.describe()
# Out:
#        Engine_Size  Cylinders  Horsepower       Weight   Model_Year  \
# count    10.000000  10.000000   10.000000    10.000000    10.000000
# mean      2.620000   5.000000  186.500000  1570.000000  2015.400000
# std       0.781452   1.414214   57.448044   302.030168     1.776388
# min       1.600000   4.000000  110.000000  1150.000000  2012.000000
# 25%       2.050000   4.000000  152.500000  1362.500000  2014.250000
# 50%       2.450000   4.000000  172.500000  1525.000000  2015.500000
# 75%       3.150000   6.000000  215.000000  1775.000000  2016.750000
# max       4.000000   8.000000  300.000000  2100.000000  2018.000000
#
#        Acceleration        MPG
# count     10.000000  10.000000
# mean       9.560000  24.300000
# std        1.561481   4.967673
# min        7.200000  16.000000
# 25%        8.475000  21.250000
# 50%        9.650000  24.500000
# 75%       10.375000  27.500000
# max       12.500000  32.000000

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df.columns
# Out:
# Index(['Engine_Size', 'Cylinders', 'Horsepower', 'Weight', 'Model_Year',
#        'Acceleration', 'MPG'],
#       dtype='object')

# %%
X=df[['Horsepower','Acceleration','Engine_Size']]
Y=df['MPG']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=LinearRegression()

# %%
x=model.fit(X_train,Y_train)
x
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# np.float64(16.487154309583623)

# %%
model.coef_
# Out:
# array([-0.01296891,  1.62061064, -2.04675499])

# %%
Y_pred=model.predict(X_test)
Y_pred
# Out:
# array([19.04616966, 28.94375417])

# %%
mse=mean_squared_error(Y_test,Y_pred)
rmse=np.sqrt(mse)
r2=r2_score(Y_test,Y_pred)

# %%
print(mse)
print(rmse)
print(r2)
# Out:
# 0.5588934478367096
# 0.7475917654955206
# 0.9815241835425881

# %%
import matplotlib.pyplot as plt

residuals = Y_test-Y_pred

plt.scatter(Y_pred, residuals)
plt.axhline(0, color='red')
plt.xlabel("Predicted MPG")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()
