# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Car_CO2_DTR.csv")

# %%
df
# Out:
#      Engine_Size_L  Cylinders  Weight_kg  CO2_Emissions
# 0             5.60         11    2712.22         520.75
# 1             4.21          4    2344.63         309.61
# 2             4.77          5    1917.22         337.96
# 3             1.70          6    2845.65         222.18
# 4             1.44          3    2827.10         172.64
# ..             ...        ...        ...            ...
# 155           3.89          7    2103.36         337.33
# 156           5.99          5    1889.58         455.05
# 157           2.77          4    2479.48         234.65
# 158           1.10         11    2980.33         271.85
# 159           1.50          7    1010.57         166.97
#
# [160 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Engine_Size_L  160 non-null    float64
#  1   Cylinders      160 non-null    int64
#  2   Weight_kg      160 non-null    float64
#  3   CO2_Emissions  160 non-null    float64
# dtypes: float64(3), int64(1)
# memory usage: 5.1 KB

# %%
df.describe()
# Out:
#        Engine_Size_L   Cylinders    Weight_kg  CO2_Emissions
# count     160.000000  160.000000   160.000000     160.000000
# mean        3.314938    6.887500  1943.180375     303.432125
# std         1.445430    2.490201   617.679361      89.474624
# min         1.060000    3.000000   840.490000     133.880000
# 25%         2.240000    5.000000  1468.977500     234.740000
# 50%         3.110000    7.000000  1921.300000     292.275000
# 75%         4.592500    9.000000  2438.920000     355.425000
# max         5.990000   11.000000  2996.410000     520.750000

# %%
df.columns
# Out:
# Index(['Engine_Size_L', 'Cylinders', 'Weight_kg', 'CO2_Emissions'], dtype='object')

# %%
x=df[['Engine_Size_L', 'Cylinders', 'Weight_kg']].values
y=df['CO2_Emissions'].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor
reg_tree=DecisionTreeRegressor(
    random_state=42,
    max_depth=4,
    min_samples_leaf=2,
    min_samples_split=6
)
reg_tree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=4, min_samples_leaf=2, min_samples_split=6,
#                       random_state=42)

# %%
y_pred=reg_tree.predict(x_test)

# %%
from sklearn.metrics import(
    mean_squared_error,
    mean_absolute_error,
    r2_score
)
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print("mse:",mse)
print("rmse:",rmse)
print("mae:",mae)
print("r2:",r2)
# Out:
# mse: 997.7475403547188
# rmse: 31.587142009917876
# mae: 25.22909803921568
# r2: 0.8411320071605652

# %%
from sklearn.model_selection import GridSearchCV
params = {
    "max_depth": [3, 4, 5, 6, 7, 8, None],
    "min_samples_split": [2, 4, 6, 10],
    "min_samples_leaf": [1, 2, 4, 6],
}

grid = GridSearchCV(
    estimator=DecisionTreeRegressor(random_state=42),
    param_grid=params,
    cv=5,
    scoring="r2",
    n_jobs=-1  # optional: use all cores
)

grid.fit(x_train, y_train)  # make sure it's X_train, y_train

print("Best params:", grid.best_params_)
print("Best CV R²:", grid.best_score_)
# Out:
# Best params: {'max_depth': 7, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Best CV R²: 0.8869888405196701

# %%
reg_tree=DecisionTreeRegressor(
    random_state=42,
    max_depth=7,
    min_samples_leaf=2,
    min_samples_split=2
)
reg_tree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=7, min_samples_leaf=2, random_state=42)

# %%
y_pred=reg_tree.predict(x_test)

# %%
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print("mse:",mse)
print("rmse:",rmse)
print("mae:",mae)
print("r2:",r2)
# Out:
# mse: 683.1382977057292
# rmse: 26.136914464139206
# mae: 21.378661458333337
# r2: 0.8912261811743747

# %%
df.columns
# Out:
# Index(['Engine_Size_L', 'Cylinders', 'Weight_kg', 'CO2_Emissions'], dtype='object')

# %%
new=pd.DataFrame({
    "Actual_Score":y_test,
    "Predicted":y_pred

})
new
# Out:
#     Actual_Score   Predicted
# 0         191.72  201.750000
# 1         133.88  158.100000
# 2         313.01  341.763333
# 3         274.34  327.240000
# 4         138.63  158.100000
# 5         184.64  171.383333
# 6         365.37  411.145000
# 7         291.50  331.610000
# 8         282.58  281.210000
# 9         160.54  158.100000
# 10        473.61  441.580000
# 11        227.54  183.390000
# 12        276.91  238.356000
# 13        420.23  417.035000
# 14        286.05  286.835000
# 15        321.69  307.313333
# 16        260.59  243.390000
# 17        264.50  276.010000
# 18        419.47  424.380000
# 19        334.68  302.990000
# 20        253.97  229.770000
# 21        261.41  255.792500
# 22        390.15  427.245000
# 23        352.87  330.165000
# 24        293.05  299.505000
# 25        257.17  219.160000
# 26        284.31  289.430000
# 27        345.26  302.990000
# 28        173.57  158.100000
# 29        290.81  286.835000
# 30        300.32  276.010000
# ...

# %%
df.columns
# Out:
# Index(['Engine_Size_L', 'Cylinders', 'Weight_kg', 'CO2_Emissions'], dtype='object')

# %%
df.head()
# Out:
#    Engine_Size_L  Cylinders  Weight_kg  CO2_Emissions
# 0           5.60         11    2712.22         520.75
# 1           4.21          4    2344.63         309.61
# 2           4.77          5    1917.22         337.96
# 3           1.70          6    2845.65         222.18
# 4           1.44          3    2827.10         172.64

# %%
new1=np.array([[
    4.5,
    7,
    2543.54
]])
predicted_value=reg_tree.predict(new1)
predicted_value
# Out:
# array([357.855])
