# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv("Weather_Electricity_DTR.csv")

# %%
df
# Out:
#      Temperature_C  Humidity_%  WindSpeed_kmh  Electricity_Consumption
# 0            30.17       30.00           6.42                   265.81
# 1            24.64       26.05          19.53                   239.94
# 2            34.76       77.33           5.98                   255.04
# 3            10.94       87.43          17.28                    -3.00
# 4            34.24       73.27           8.60                   245.61
# ..             ...         ...            ...                      ...
# 145          16.95       63.26          17.80                   110.53
# 146          14.61       52.23           5.29                    54.51
# 147          28.92       71.84           2.92                   191.24
# 148          11.10       46.38           2.67                    44.79
# 149          33.88       73.93           9.77                   232.44
#
# [150 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Temperature_C            150 non-null    float64
#  1   Humidity_%               150 non-null    float64
#  2   WindSpeed_kmh            150 non-null    float64
#  3   Electricity_Consumption  150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
df.describe()
# Out:
#        Temperature_C  Humidity_%  WindSpeed_kmh  Electricity_Consumption
# count     150.000000  150.000000     150.000000               150.000000
# mean       25.200667   56.269000      10.199333               180.338267
# std         8.696118   20.427229       5.626488               105.524610
# min        10.200000   20.980000       0.000000                -3.000000
# 25%        17.052500   40.470000       5.352500                92.597500
# 50%        25.775000   55.485000      10.465000               179.675000
# 75%        32.952500   73.902500      14.575000               255.017500
# max        39.860000   89.960000      19.980000               395.460000

# %%
df.columns
# Out:
# Index(['Temperature_C', 'Humidity_%', 'WindSpeed_kmh',
#        'Electricity_Consumption'],
#       dtype='object')

# %%
x=df[['Temperature_C', 'Humidity_%', 'WindSpeed_kmh']].values
y=df['Electricity_Consumption']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor
reg_tree=DecisionTreeRegressor(
    random_state=42,
    max_depth=4,
    min_samples_leaf=2,
    min_samples_split=4
)
reg_tree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=4, min_samples_leaf=2, min_samples_split=4,
#                       random_state=42)

# %%
y_pred=reg_tree.predict(x_test)

# %%
from sklearn.metrics import(
    mean_squared_error,
    mean_absolute_error,
    r2_score
)
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print("mse:",mse)
print("rmse:",rmse)
print("mae:",mae)
print("r2:",r2)
# Out:
# mse: 923.2100221796775
# rmse: 30.384371347448962
# mae: 26.061956613756607
# r2: 0.9131577460026439

# %%
from sklearn.model_selection import GridSearchCV
params={
    "max_depth":[3,4,5,6,7,8,None],
    "min_samples_leaf":[2,4,6,10],
    "min_samples_split":[1,2,4,6]
}
grid=GridSearchCV(
    estimator=DecisionTreeRegressor(random_state=42),
    param_grid=params,
    cv=5,
    scoring="r2",
)
grid.fit(x_train, y_train)  # make sure it's X_train, y_train

print("Best params:", grid.best_params_)
print("Best CV R²:", grid.best_score_)
# Out:
# Best params: {'max_depth': 8, 'min_samples_leaf': 2, 'min_samples_split': 6}
# Best CV R²: 0.9377287724096105
# c:\Users\husna\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 140 fits failed out of a total of 560.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 140 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\husna\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\husna\anaconda3\Lib\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\husna\anaconda3\Lib\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\husna\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'min_samples_split' parameter of DecisionTreeRegressor must be an int in the range [2, inf) or a float in the range (0.0, 1.0]. Got 1 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\husna\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [       nan 0.89444468 0.89444468 0.89444468        nan 0.88979291
#  0.88979291 0.88979291        nan 0.87612408 0.87612408 0.87612408
#         nan 0.87787654 0.87787654 0.87787654        nan 0.92584781
#  0.92584781 0.92539583        nan 0.92180761 0.92180761 0.92180761
#         nan 0.90431956 0.90431956 0.90431956        nan 0.88442906
#  0.88442906 0.88442906        nan 0.92854938 0.92854938 0.93341663
#         nan 0.91853319 0.91853319 0.91853319        nan 0.90549896
#  0.90549896 0.90549896        nan 0.88442906 0.88442906 0.88442906
#         nan 0.93490505 0.93490505 0.93641888        nan 0.91821573
#  0.91821573 0.91821573        nan 0.90549896 0.90549896 0.90549896
#         nan 0.88442906 0.88442906 0.88442906        nan 0.93693547
#  0.93693547 0.93758374        nan 0.91692112 0.91692112 0.91692112
#         nan 0.90549896 0.90549896 0.90549896        nan 0.88442906
#  0.88442906 0.88442906        nan 0.93751395 0.93751395 0.93772877
#         nan 0.91692112 0.91692112 0.91692112        nan 0.90549896
#  0.90549896 0.90549896        nan 0.88442906 0.88442906 0.88442906
#         nan 0.93742862 0.93742862 0.93772877        nan 0.91692112
#  0.91692112 0.91692112        nan 0.90549896 0.90549896 0.90549896
#         nan 0.88442906 0.88442906 0.88442906]
#   warnings.warn(

# %%
reg_tree=DecisionTreeRegressor(
    random_state=42,
    max_depth=8,
    min_samples_leaf=2,
    min_samples_split=6,
)
reg_tree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=8, min_samples_leaf=2, min_samples_split=6,
#                       random_state=42)

# %%
y_pred=reg_tree.predict(x_test)

# %%
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print("mse:",mse)
print("rmse:",rmse)
print("mae:",mae)
print("r2:",r2)
# Out:
# mse: 652.284368672222
# rmse: 25.5398584309354
# mae: 20.586411111111108
# r2: 0.938642515287043

# %%
new=pd.DataFrame({
    "Actual_Score": y_test,
    "Predicted_Score": y_pred,
})
print(new)
# Out:
#      Actual_Score  Predicted_Score
# 73           0.02        20.290000
# 18           0.56        56.480000
# 118         87.50        85.890000
# 78         128.28        85.890000
# 76         261.81       258.705000
# 31          38.36        20.290000
# 64         271.21       229.815000
# 141        325.76       281.956667
# 68         112.92        92.365000
# 82         252.20       231.310000
# 110        182.43       177.325000
# 12         119.47       117.810000
# 36         310.28       311.306667
# 9           -0.49        34.637500
# 19         304.14       318.122500
# 56         106.45       149.095000
# 104        395.46       383.470000
# 69         220.68       228.346667
# 55         243.90       258.705000
# 132        236.62       226.143333
# 29          71.63        56.480000
# 127         93.91        92.365000
# 26         211.66       184.373333
# 128        233.48       196.665000
# 131        149.51       184.373333
# 145        110.53        92.365000
# 108        160.95       149.095000
# 143        144.67       110.736000
# 45         278.53       258.705000
# 30          80.23        85.890000

# %%
df.columns
# Out:
# Index(['Temperature_C', 'Humidity_%', 'WindSpeed_kmh',
#        'Electricity_Consumption'],
#       dtype='object')

# %%
new1=np.array([[
    33.7,
    12.8,
    11.7
]])
predicted_value=reg_tree.predict(new1)
predicted_value
# Out:
# array([318.1225])
